# %% [markdown]
# ### Prepare Ratings Dataframe

# %%
import pandas as pd

ratings = pd.read_csv("data/ml_small/ratings.csv")
ratings.drop(labels=["timestamp"], axis=1, inplace=True)
ratings.rename(columns={'userId': 'user_id', 'movieId': 'movie_id'}, inplace=True)
display(ratings)
nan_ratio = ratings.isna().mean()
print("NaN Ratios")
print(nan_ratio)
# Out:
#         user_id  movie_id  rating
# 0             1         1     4.0
# 1             1         3     4.0
# 2             1         6     4.0
# 3             1        47     5.0
# 4             1        50     5.0
# ...         ...       ...     ...
# 100831      610    166534     4.0
# 100832      610    168248     5.0
# 100833      610    168250     5.0
# 100834      610    168252     5.0
# 100835      610    170875     3.0
#
# [100836 rows x 3 columns]
# NaN Ratios
# user_id     0.0
# movie_id    0.0
# rating      0.0
# dtype: float64

# %% [markdown]
# ### Sample and Split
# The original dataset includes > 100k ratings. This is too much for this usecase.

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# Step 1: Get unique user IDs
unique_user_ids = ratings['user_id'].unique()

# Step 2: Shuffle the user IDs
np.random.shuffle(unique_user_ids)

# Step 3: Split the user IDs into two parts
split_index = len(unique_user_ids) // 10
user_ids_split_1 = unique_user_ids[:split_index]
user_ids_split_2 = unique_user_ids[split_index:]

# Step 4: Create the splits in the DataFrame
df_split_1 = ratings[ratings['user_id'].isin(user_ids_split_1)]
df_split_2 = ratings[ratings['user_id'].isin(user_ids_split_2)]

# Step 5: Train test split stratified on user_id column so that all user_ids of test set are known already in train set
ratings_reduced = df_split_1
ratings_train, ratings_test = train_test_split(ratings, test_size=0.3, stratify=ratings['user_id'], random_state=11717659)

assert set(ratings_train['user_id']) == set(ratings_test['user_id'])

unique_movie_ids = ratings_reduced["movie_id"].unique()

# %% [markdown]
# ### Prepare Movies Dataframe
# Remove movies that are not rated

# %%
movies = pd.read_csv("data/ml_small/movies.csv")
movies.rename(columns={'movieId': 'movie_id'}, inplace=True)
# Remove movies that are are never rated in train or test set
movies = movies[movies["movie_id"].isin(unique_movie_ids)]

movies["genres"] = movies["genres"].str.split("|")
movies["year"] = movies["title"].str.extract(r'\((\d{4})\)')
movies['year'] = pd.to_numeric(movies['year'], errors='coerce')
movies['year'] = movies['year'].fillna(movies["year"].median()).astype(int)
movies["genres"] = movies["genres"].apply(lambda x: [] if x == ["(no genres listed)"] else x)

display(movies)
nan_ratio = movies.isna().mean()
print("NaN Ratios")
print(nan_ratio)
# Out:
#       movie_id                                title  \
# 0            1                     Toy Story (1995)
# 1            2                       Jumanji (1995)
# 2            3              Grumpier Old Men (1995)
# 3            4             Waiting to Exhale (1995)
# 4            5   Father of the Bride Part II (1995)
# ...        ...                                  ...
# 9709    187593                    Deadpool 2 (2018)
# 9710    187595       Solo: A Star Wars Story (2018)
# 9715    188751  Mamma Mia: Here We Go Again! (2018)
# 9716    188797                           Tag (2018)
# 9722    189547                  Iron Soldier (2010)
#
#                                                  genres  year
# 0     [Adventure, Animation, Children, Comedy, Fantasy]  1995
# 1                        [Adventure, Children, Fantasy]  1995
# 2                                     [Comedy, Romance]  1995
# 3                              [Comedy, Drama, Romance]  1995
# 4                                              [Comedy]  1995
# ...                                                 ...   ...
# 9709                           [Action, Comedy, Sci-Fi]  2018
# 9710              [Action, Adventure, Children, Sci-Fi]  2018
# 9715                                  [Comedy, Romance]  2018
# 9716                                           [Comedy]  2018
# 9722                                   [Action, Sci-Fi]  2010
#
# [3846 rows x 4 columns]
# NaN Ratios
# movie_id    0.0
# title       0.0
# genres      0.0
# year        0.0
# dtype: float64

# %% [markdown]
# ### Populate Neo4j Database as Knowledge Graph

# %%
from neo4j import GraphDatabase
URI = "neo4j://localhost:7687"
AUTH = ("neo4j", "password")

# %%
def reset_db(driver):
    driver.execute_query(
    "MATCH (n)"
    "DETACH DELETE n",
    database_="neo4j")

# %%
def create_movies(driver):
    for _, row in movies.iterrows():
        driver.execute_query(
            """
            MERGE (m:Movie {movie_id: $movie_id, title: $title})
            MERGE (y:Year {year: $year})
            MERGE (m)-[:RELEASED_IN]->(y)
            """,
            movie_id = row["movie_id"], title = row["title"],
            year = row["year"], database_ = "neo4j")
        for genre in row["genres"]:
            driver.execute_query(
                """
                MATCH (m:Movie {movie_id: $movie_id})
                MERGE (g:Genre {name: $genre})
                MERGE (m)-[:OF_GENRE]->(g)
                """,
                movie_id = row["movie_id"], title = row["title"],
                genre = genre, year = row["year"], database_ = "neo4j")
            pass

# %%
def create_user_ratings(driver):
    for _, row in ratings_train.iterrows():
        driver.execute_query(
            """
            CREATE (u:User {user_id: $user_id})
            WITH u
            MATCH (m:Movie {movie_id: $movie_id})
            CREATE (u)-[:RATED {rating: $rating}]->(m)
            """,
            user_id = row["user_id"], movie_id = row["movie_id"], 
            rating = row["rating"], database_ = "neo4j")

# %%
with GraphDatabase.driver(URI, auth=AUTH) as driver:
    reset_db(driver)
    create_movies(driver)
    create_user_ratings(driver)
# Out:
# Unable to retrieve routing information
# Transaction failed and will be retried in 0.9453360857485203s (Unable to retrieve routing information)
# Unable to retrieve routing information
# Transaction failed and will be retried in 1.6812503568037032s (Unable to retrieve routing information)
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File d:\STONKSKG\Lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:528, in BoltSocket._connect(cls, resolved_address, timeout, keep_alive)
#     527 log.debug("[#0000]  C: <OPEN> %s", resolved_address)
# --> 528 s.connect(resolved_address)
#     529 s.settimeout(t)
#
# ConnectionRefusedError: [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 with GraphDatabase.driver(URI, auth=AUTH) as driver:
# ----> 2     reset_db(driver)
#       3     create_movies(driver)
#       4     create_user_ratings(driver)
#
# Cell In[5], line 2, in reset_db(driver)
#       1 def reset_db(driver):
# ----> 2     driver.execute_query(
#       3     "MATCH (n)"
#       4     "DETACH DELETE n",
#       5     database_="neo4j")
#
# File d:\STONKSKG\Lib\site-packages\neo4j\_sync\driver.py:959, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     956     raise ValueError("Invalid routing control value: %r"
#     957                      % routing_)
#     958 with session._pipelined_begin:
# --> 959     return session._run_transaction(
#     960         access_mode, TelemetryAPI.DRIVER,
#     961         work, (query_str, parameters, result_transformer_), {}
#     962     )
#
# File d:\STONKSKG\Lib\site-packages\neo4j\_sync\work\session.py:545, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     543 while True:
#     544     try:
# --> 545         self._open_transaction(
#     546             tx_cls=ManagedTransaction,
#     547             api=None if telemetry_sent else api,
#     548             access_mode=access_mode, metadata=metadata,
#     549             timeout=timeout, api_success_cb=api_success_cb,
#     550         )
#     551         assert isinstance(self._transaction, ManagedTransaction)
#     552         tx = self._transaction
#
# File d:\STONKSKG\Lib\site-packages\neo4j\_sync\work\session.py:424, in Session._open_transaction(self, tx_cls, access_mode, api, metadata, timeout, api_success_cb)
#     413 def _open_transaction(
#     414     self,
#     415     *,
#    (...)
#     422     api_success_cb: t.Optional[t.Callable[[dict], None]] = None,
#     423 ) -> None:
# --> 424     self._connect(access_mode=access_mode)
#     425     assert self._connection is not None
#     426     if api is not None:
#
# File d:\STONKSKG\Lib\site-packages\neo4j\_sync\work\session.py:130, in Session._connect(self, access_mode, **acquire_kwargs)
#     128     access_mode = self._config.default_access_mode
#     129 try:
# --> 130     super()._connect(
#     131         access_mode, auth=self._config.auth, **acquire_kwargs
#     132     )
#     133 except asyncio.CancelledError:
#     134     self._handle_cancellation(message="_connect")
#
# File d:\STONKSKG\Lib\site-packages\neo4j\_sync\work\workspace.py:182, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     173 acquire_kwargs_ = {
#     174     "access_mode": access_mode,
#     175     "timeout": acquisition_timeout,
#    (...)
#     179     "liveness_check_timeout": None,
#     180 }
#     181 acquire_kwargs_.update(acquire_kwargs)
# --> 182 self._connection = self._pool.acquire(**acquire_kwargs_)
#     183 self._connection_access_mode = access_mode
#
# File d:\STONKSKG\Lib\site-packages\neo4j\_sync\io\_pool.py:910, in Neo4jPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout)
#     903 #     await self.ensure_routing_table_is_fresh(
#     904 #         access_mode=access_mode, database=database, imp_user=None,
#     905 #         bookmarks=bookmarks, acquisition_timeout=timeout
#     906 #     )
#     908 log.debug("[#0000]  _: <POOL> acquire routing connection, "
#     909           "access_mode=%r, database=%r", access_mode, database)
# --> 910 self.ensure_routing_table_is_fresh(
#     911     access_mode=access_mode, database=database,
#     912     imp_user=None, bookmarks=bookmarks, auth=auth,
#     913     acquisition_timeout=timeout
#     914 )
#     916 while True:
#     917     try:
#     918         # Get an address for a connection that have the fewest in-use
#     919         # connections.
#
# File d:\STONKSKG\Lib\site-packages\neo4j\_sync\io\_pool.py:852, in Neo4jPool.ensure_routing_table_is_fresh(self, access_mode, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback)
#     848     log.debug("[#0000]  _: <POOL> using existing routing table %r",
#     849               routing_table)
#     850     return False
# --> 852 self.update_routing_table(
#     853     database=database, imp_user=imp_user, bookmarks=bookmarks,
#     854     auth=auth, acquisition_timeout=acquisition_timeout,
#     855     database_callback=database_callback
#     856 )
#     857 self.update_connection_pool(database=database)
#     859 return True
#
# File d:\STONKSKG\Lib\site-packages\neo4j\_sync\io\_pool.py:774, in Neo4jPool.update_routing_table(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback)
#     769 prefer_initial_routing_address = \
#     770     self.routing_tables[database].initialized_without_writers
#     772 if prefer_initial_routing_address:
#     773     # TODO: Test this state
# --> 774     if self._update_routing_table_from(
#     775         self.address, database=database,
#     776         imp_user=imp_user, bookmarks=bookmarks, auth=auth,
#     777         acquisition_timeout=acquisition_timeout,
#     778         database_callback=database_callback
#     779     ):
#     780         # Why is only the first initial routing address used?
#     781         return
#     782 if self._update_routing_table_from(
#     783     *(existing_routers - {self.address}), database=database,
#     784     imp_user=imp_user, bookmarks=bookmarks, auth=auth,
#     785     acquisition_timeout=acquisition_timeout,
#     786     database_callback=database_callback
#     787 ):
#
# File d:\STONKSKG\Lib\site-packages\neo4j\_sync\io\_pool.py:720, in Neo4jPool._update_routing_table_from(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback, *routers)
#     716 for router in routers:
#     717     for address in NetworkUtil.resolve_address(
#     718         router, resolver=self.pool_config.resolver
#     719     ):
# --> 720         new_routing_table = self.fetch_routing_table(
#     721             address=address, acquisition_timeout=acquisition_timeout,
#     722             database=database, imp_user=imp_user, bookmarks=bookmarks,
#     723             auth=auth
#     724         )
#     725         if new_routing_table is not None:
#     726             new_database = new_routing_table.database
#
# File d:\STONKSKG\Lib\site-packages\neo4j\_sync\io\_pool.py:657, in Neo4jPool.fetch_routing_table(self, address, acquisition_timeout, database, imp_user, bookmarks, auth)
#     655 new_routing_info = None
#     656 try:
# --> 657     new_routing_info = self.fetch_routing_info(
#     658         address, database, imp_user, bookmarks, auth,
#     659         acquisition_timeout
#     660     )
#     661 except Neo4jError as e:
#     662     # checks if the code is an error that is caused by the client. In
#     663     # this case there is no sense in trying to fetch a RT from another
#     664     # router. Hence, the driver should fail fast during discovery.
#     665     if e._is_fatal_during_discovery():
#
# File d:\STONKSKG\Lib\site-packages\neo4j\_sync\io\_pool.py:625, in Neo4jPool.fetch_routing_info(self, address, database, imp_user, bookmarks, auth, acquisition_timeout)
#     623     auth = copy(auth)
#     624     auth.force_auth = False
# --> 625 cx = self._acquire(address, auth, deadline, None)
#     626 try:
#     627     routing_table = cx.route(
#     628         database=database or self.workspace_config.database,
#     629         imp_user=imp_user or self.workspace_config.impersonated_user,
#     630         bookmarks=bookmarks
#     631     )
#
# File d:\STONKSKG\Lib\site-packages\neo4j\_sync\io\_pool.py:313, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout)
#     308             raise ClientError(
#     309                 "failed to obtain a connection from the pool within "
#     310                 "{!r}s (timeout)".format(deadline.original_timeout)
#     311             )
#     312 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 313 return connection_creator()
#
# File d:\STONKSKG\Lib\site-packages\neo4j\_sync\io\_pool.py:163, in IOPool._acquire_new_later.<locals>.connection_creator()
#     161 try:
#     162     try:
# --> 163         connection = self.opener(
#     164             address, auth or self.pool_config.auth, deadline
#     165         )
#     166     except ServiceUnavailable:
#     167         self.deactivate(address)
#
# File d:\STONKSKG\Lib\site-packages\neo4j\_sync\io\_pool.py:557, in Neo4jPool.open.<locals>.opener(addr, auth_manager, deadline)
#     556 def opener(addr, auth_manager, deadline):
# --> 557     return Bolt.open(
#     558         addr, auth_manager=auth_manager, deadline=deadline,
#     559         routing_context=routing_context, pool_config=pool_config
#     560     )
#
# File d:\STONKSKG\Lib\site-packages\neo4j\_sync\io\_bolt.py:403, in Bolt.open(cls, address, auth_manager, deadline, routing_context, pool_config)
#     399 if deadline is None:
#     400     deadline = Deadline(None)
#     402 s, protocol_version, handshake, data = \
# --> 403     BoltSocket.connect(
#     404         address,
#     405         tcp_timeout=pool_config.connection_timeout,
#     406         deadline=deadline,
#     407         custom_resolver=pool_config.resolver,
#     408         ssl_context=pool_config.get_ssl_context(),
#     409         keep_alive=pool_config.keep_alive,
#     410     )
#     412 pool_config.protocol_version = protocol_version
#     414 # Carry out Bolt subclass imports locally to avoid circular dependency
#     415 # issues.
#
# File d:\STONKSKG\Lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:690, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     688 s = None
#     689 try:
# --> 690     s = BoltSocket._connect(resolved_address, tcp_timeout,
#     691                             keep_alive)
#     692     s = BoltSocket._secure(s, resolved_address._host_name,
#     693                            ssl_context)
#     694     return BoltSocket._handshake(s, resolved_address, deadline)
#
# File d:\STONKSKG\Lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:542, in BoltSocket._connect(cls, resolved_address, timeout, keep_alive)
#     537     raise ServiceUnavailable(
#     538         "Timed out trying to establish connection to {!r}".format(
#     539             resolved_address))
#     540 except Exception as error:
#     541     log.debug("[#0000]  S: <ERROR> %s %s", type(error).__name__,
# --> 542               " ".join(map(repr, error.args)))
#     543     log.debug("[#0000]  C: <CLOSE> %s", resolved_address)
#     544     cls._kill_raw_socket(s)
#
# KeyboardInterrupt:
